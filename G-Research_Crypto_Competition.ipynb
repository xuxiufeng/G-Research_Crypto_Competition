# %% [markdown]
# <a href="https://colab.research.google.com/github/xuxiufeng/G-Research_Crypto_Competition/blob/main/G-Research_Crypto_Competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I - Download Dataset

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-32aab930-71a2-454c-b290-42a2f7d43187" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32aab930-71a2-454c-b290-42a2f7d43187">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle competitions download -c g-research-crypto-forecasting
# Out:
# ...
#  99% 1.12G/1.13G [00:10<00:00, 155MB/s]
# 100% 1.13G/1.13G [00:10<00:00, 119MB/s]

# %%
# !unzip g-research-crypto-forecasting.zip -d g-research-crypto-forecasting # unzip
# Out:
# error:  must specify directory to which to extract with -d option

# %% [markdown]
# # II - Data Description

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
data_folder = "./g-research-crypto-forecasting/"
# !ls $data_folder
# Out:
# asset_details.csv	       example_test.csv  supplemental_train.csv
# example_sample_submission.csv  gresearch_crypto  train.csv

# %%
crypto_df = pd.read_csv(data_folder + 'train.csv')

# %%
crypto_df.head(10)
# Out:
#     timestamp  Asset_ID  Count          Open        High         Low  \
# 0  1514764860         2   40.0   2376.580000   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.530000      8.5300      8.5300
# 2  1514764860         1  229.0  13835.194000  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.659600      7.6596      7.6567
# 4  1514764860         7    5.0     25.920000     25.9200     25.8740
# 5  1514764860         6  173.0    738.302500    746.0000    732.5100
# 6  1514764860         9  167.0    225.330000    227.7800    222.9800
# 7  1514764860        11    7.0    329.090000    329.8800    329.0900
# 8  1514764920         2   53.0   2374.553333   2400.9000   2354.2000
# 9  1514764920         0    7.0      8.530000      8.5300      8.5145
#
#           Close       Volume          VWAP    Target
# 0   2374.590000    19.233005   2373.116392 -0.004218
# 1      8.530000    78.380000      8.530000 -0.014399
# ...

# %%
asset_details = pd.read_csv(data_folder + 'asset_details.csv')
asset_details
# Out:
#     Asset_ID    Weight        Asset_Name
# 0          2  2.397895      Bitcoin Cash
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 3          5  1.386294            EOS.IO
# 4          7  2.079442  Ethereum Classic
# 5          6  5.894403          Ethereum
# 6          9  2.397895          Litecoin
# 7         11  1.609438            Monero
# 8         13  1.791759              TRON
# 9         12  2.079442           Stellar
# 10         3  4.406719           Cardano
# 11         8  1.098612              IOTA
# 12        10  1.098612             Maker
# 13         4  3.555348          Dogecoin

# %%
btc = crypto_df[crypto_df["Asset_ID"]==1].set_index("timestamp") # Asset_ID = 1 for Bitcoin    set_index remove index
btc_mini = btc.iloc[-200:] # Select recent data rows
btc_mini
# Out:
#             Asset_ID   Count          Open          High       Low  \
# timestamp
# 1632170460         1  5694.0  43558.393750  43588.680000  43427.28
# 1632170520         1  2528.0  43449.818571  43495.954028  43414.33
# 1632170580         1  3985.0  43427.082310  43455.218478  43327.29
# 1632170640         1  2185.0  43362.572857  43454.990000  43348.06
# 1632170700         1  2623.0  43419.832500  43467.000000  43351.15
# ...              ...     ...           ...           ...       ...
# 1632182160         1  1940.0  42983.780000  43001.850849  42878.26
# 1632182220         1  2026.0  42904.197143  42932.000000  42840.16
# 1632182280         1  1986.0  42859.385714  42887.500000  42797.20
# 1632182340         1  4047.0  42839.012802  43042.160000  42818.10
# 1632182400         1  2698.0  43009.961250  43048.510000  42961.64
#
#                    Close      Volume          VWAP    Target
# timestamp
# 1632170460  43447.003750  191.442881  43493.981877 -0.000805
# ...
